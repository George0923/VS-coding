# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
from ipywidgets import interact

# %% [markdown]
# # 輸入圖片檔

# %%
shirt1 = mpimg.imread('shirt1.jpg')
plt.savefig('fig_Tshirt1.jpg');
shirt2 = mpimg.imread('shirt2.jpg')
plt.savefig('fig_shirt2.jpg');
shirt3 = mpimg.imread('shirt3.jpg')
plt.savefig('fig_shirt3.jpg');
shirt4 = mpimg.imread('shirt4.jpg')
plt.savefig('fig_shirt4.jpg');
shirt5 = mpimg.imread('shirt5.jpg')
plt.savefig('fig_shirt5.jpg');
pant1 = mpimg.imread('pant1.jpg')
plt.savefig('fig_pant1.jpg');
pant2 = mpimg.imread('pant2.jpg')
plt.savefig('fig_pant2.jpg');
pant3 = mpimg.imread('pant3.jpg')
plt.savefig('fig_pant3.jpg');
pant4 = mpimg.imread('pant4.jpg')
plt.savefig('fig_pant4.jpg');
pant5 = mpimg.imread('pant5.jpg')
plt.savefig('fig_pant5.jpg');
coat1 = mpimg.imread('coat1.jpg')
plt.savefig('fig_coat1.jpg');
coat2 = mpimg.imread('coat2.jpg')
plt.savefig('fig_coat2.jpg');
coat3 = mpimg.imread('coat3.jpg')
plt.savefig('fig_coat3.jpg');
shoes1 = mpimg.imread('shoes1.jpg')
plt.savefig('fig_shoes1.jpg');
shoes2 = mpimg.imread('shoes2.png')
plt.savefig('fig_shoes2.png');
shoes3 = mpimg.imread('shoes3.jpg')
plt.savefig('fig_shoes3.jpg');
shoes4 = mpimg.imread('shoes4.jpg')
plt.savefig('fig_shoes4.jpg');

# %%
def f(choice):
    print(choice)
    if choice == "上衣":
        x = random.randint(1,5)
        if x == 1:
            plt.imshow(shirt1);
            plt.axis('off');
        if x == 2:
            plt.imshow(shirt2);
            plt.axis('off');
        if x == 3:
            plt.imshow(shirt3);
            plt.axis('off');
        if x == 4:
            plt.imshow(shirt4);
            plt.axis('off');
        if x == 5:
            plt.imshow(shirt5);
            plt.axis('off');
    if choice == "褲子":
        y = random.randint(1,5)
        if y == 1:
            plt.imshow(pant1);
            plt.axis('off');
        if y == 2:
            plt.imshow(pant2);
            plt.axis('off');
        if y == 3:
            plt.imshow(pant3);
            plt.axis('off');
        if y == 4:
            plt.imshow(pant4);
            plt.axis('off');
        if y == 5:
            plt.imshow(pant5);
            plt.axis('off');
    if choice == "鞋子":
        z = random.randint(1,4)
        if z == 1:
            plt.imshow(shoes1);
            plt.axis('off');
        if z == 2:
            plt.imshow(shoes2);
            plt.axis('off');
        if z == 3:
            plt.imshow(shoes3);
            plt.axis('off');
        if z == 4:
            plt.imshow(shoes4);
            plt.axis('off');
    if choice == "外套":
        X = random.randint(1,3)
        if X == 1:
            plt.imshow(coat1);
            plt.axis('off');
        if X == 2:
            plt.imshow(coat2);
            plt.axis('off');
        if X == 3:
            plt.imshow(coat3);
            plt.axis('off');

# %%
interact(f, choice = {"上衣", "褲子", "鞋子", "外套"});
# Out:
# interactive(children=(Dropdown(description='choice', options=('外套', '鞋子', '上衣', '褲子'), value='外套'), Output()),…

# %%
shirt = [shirt1, shirt2, shirt3, shirt4, shirt5]
shirt_random = random.sample(shirt, 1)
plt.imshow(shirt_random);
plt.axis('off');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e81da0ef07d9> in <module>
#       1 shirt = [shirt1, shirt2, shirt3, shirt4, shirt5]
#       2 shirt_random = random.sample(shirt, 1)
# ----> 3 plt.imshow(shirt_random);
#       4 plt.axis('off');
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
# -> 2677         None else {}), **kwargs)
#    2678     sci(__ret)
#    2679     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5658                               resample=resample, **kwargs)
#    5659
# -> 5660         im.set_data(X)
#    5661         im.set_alpha(alpha)
#    5662         if im.get_clip_path() is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     681                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     682             raise TypeError("Invalid shape {} for image data"
# --> 683                             .format(self._A.shape))
#     684
#     685         if self._A.ndim == 3:
#
# TypeError: Invalid shape (1, 1000, 1000, 3) for image data

# %%
plt.imshow(shirt1);
plt.imshow(pant1);
