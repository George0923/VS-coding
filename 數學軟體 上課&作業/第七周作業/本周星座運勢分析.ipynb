# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
x = input("請輸入您的星座:")
if x == "水瓶座":
    print("整體運勢★★★★☆：令你心動的對象將會出現，千萬別逃避自己的情感；工作上積極勤懇，敢挑重擔，成績斐然；求財之事宜多請教長者，盲目跟風則會吃虧。")
elif x == "雙魚座":
    print("整體運勢★★★☆☆：本周你待在家裡的時間會比較多，與家人的互動也會因此增加。慢慢你會發現「家」可以避開一些風險，家人能給你愛情、事業「充電」。")
elif x == "牡羊座":
    print("整體運勢★★☆☆☆：玩心太重，是你這一周正事總是做不好的主要原因。壓力大時偶爾需要放鬆，但放鬆過度便是放縱。務必減少休閒娛樂活動，讓自己收收心。")
elif x == "金牛座":
    print("整體運勢★★★☆☆：電話會是你這一周的重要道具，你的好運也與它的使用頻率息息相關。一通電話，一則訊息都將拉近你與戀人、朋友間的距離，貴人也會慢慢向你靠近。")
elif x == "雙子座":
    print("整體運勢★★★★☆：這周運勢很給力，動手能力非常強，與人相處起來也很融洽，趁著好時機，不妨解決一些平時很棘手的事，能夠有不錯的成果。")
elif x == "巨蟹座":
    print("整體運勢★★★☆☆：愉快安穩的一周，雖然會遇到言語刻薄的人，但也只是當時令你感到不爽，很快你就會被其他開心的事抹去那段討厭的記憶。")
elif x == "獅子座":
    print("整體運勢★★☆☆☆：本周強烈的好奇心會成為你自虐的匕首，總想去打聽別人的近況、瞭解未知的結果，可答案往往讓你很受傷。有些事情不知道要比知道好，沒必要給自己找虐。")
elif x == "處女座":
    print("整體運勢★★★★☆：積極樂觀的心態將會帶給你笑口常開的一周，即使偶爾遇到不愉快，也能很快釋懷。有開心的事情不妨與好朋友分享，讓快樂傳播開來。")
elif x == "天秤座":
    print("整體運勢★★☆☆☆：未來這一周總有一些大小麻煩使你忍不住要發牢騷，但每次發完牢騷後你便能釋然。只是要注意別對著無辜的對象抱怨個不停，否則會引起對方對你產生不滿。")
elif x == "天蠍座":
    print("整體運勢★★★☆☆：情緒穩定，使你做什麼都顯得很穩重。無論是工作還是學習，不管是做家務還是做投資，急則難成，穩才會離目標更近。")
elif x == "射手座":
    print("整體運勢★☆☆☆☆：你豐富的想像力本周沒能用在創意、創作上，而是用在了猜忌、假設、胡思亂想上。這對你的生活不但毫無幫助，反而會給你帶去不少的煩擾。")
elif x == "摩羯座":
    print("整體運勢★★★★★：情緒高漲，出門很容易遇到喜事。外出參加聚會的機會增多，三五個好友聚在一起，還能吸收更多的好運與歡樂。")
else:
    print("查無此星座,請確認您輸入的星座名稱是否有誤")
# Out:
# 請輸入您的星座:雙魚座
# 整體運勢★★★☆☆：本周你待在家裡的時間會比較多，與家人的互動也會因此增加。慢慢你會發現「家」可以避開一些風險，家人能給你愛情、事業「充電」。
