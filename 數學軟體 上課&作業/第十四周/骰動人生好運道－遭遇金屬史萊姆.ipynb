# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
name = input("請輸入角色名稱:")
print("金屬史萊姆出現了")
outcome_1 = ["Miss, 金屬史萊姆迅速地躲開了", "對金屬史萊姆造成3點的傷害"]
outcome_2 = ["Miss, 金屬史萊姆迅速地躲開了", "對金屬史萊姆造成2點的傷害", "對金屬史萊姆造成2點的傷害"]
outcome_3 = ["Miss, 金屬史萊姆迅速地躲開了","Miss, 金屬史萊姆迅速地躲開了","會心一擊,對金屬史萊姆造成了12點傷害"]
outcome_4 = ["Miss, 金屬史萊姆迅速地躲開了","Miss, 金屬史萊姆迅速地躲開了","會心一擊,對金屬史萊姆造成了8點傷害"]
act = ["金屬史萊姆逃走了!", "金屬史萊姆正在觀察情況。","金屬史萊姆正在觀察情況。"]
hp = 5
def rpg():
    global hp
    x = input("請選擇指令:金屬斬/隼斬/魔神斬/要害突刺")
    act_f = random.sample(act,1)
    outcome_a = random.sample(outcome_1,1)
    outcome_b = random.sample(outcome_2,1)
    outcome_c = random.sample(outcome_3,1)
    outcome_d = random.sample(outcome_4,1)
    if x == "金屬斬":
        print(name,"的攻擊,",name,"使出了金屬斬")
        if outcome_a == ["對金屬史萊姆造成3點的傷害"]:
            print(outcome_a)
            hp = hp - 3
            if hp > 0:
                print(act_f)
                if act_f == ["金屬史萊姆逃走了!"]:
                    print("怪物集團消失了")
                elif act_f == ["金屬史萊姆正在觀察情況。"]:
                    return rpg()
            elif hp <0:
                print(name,"打倒了金屬史萊姆，獲得了50G")
        elif outcome_a == ["Miss, 金屬史萊姆迅速地躲開了"]:
            print(outcome_a)
            print(act_f)
            if act_f == ["金屬史萊姆逃走了!"]:
                print("怪物集團消失了")
            elif act_f == ["金屬史萊姆正在觀察情況。"]:
                return rpg()
    elif x == "隼斬":
        print(name,"的攻擊,",name,"使出了隼斬")
        if outcome_b == ["對金屬史萊姆造成2點的傷害"]:
            print(outcome_b)
            hp = hp-2
            if hp > 0:
                print(act_f)
                if act_f == ["金屬史萊姆逃走了!"]:
                    print("怪物集團消失了")
                elif act_f == ["金屬史萊姆正在觀察情況。"]:
                    return rpg()
            elif hp < 0:
                print(name,"打倒了金屬史萊姆，獲得了50G")
        elif outcome_b == ["Miss, 金屬史萊姆迅速地躲開了"]:
            print(outcome_b)
            print(act_f)
            if act_f == ["金屬史萊姆逃走了!"]:
                print("怪物集團消失了")
            elif act_f == ["金屬史萊姆正在觀察情況。"]:
                return rpg()
    elif x == "魔神斬":
        print(name,"的攻擊,",name,"使出宛如魔神般的一擊")
        if outcome_c == ["會心一擊,對金屬史萊姆造成了12點傷害"]:
            print(outcome_c)
            hp = hp - 12
            if hp > 0:
                print(act_f)
                if act_f == ["金屬史萊姆逃走了!"]:
                    print("怪物集團消失了")
                elif act_f == ["金屬史萊姆正在觀察情況。"]:
                    return rpg()
            elif hp < 0:
                print(name,"打倒了金屬史萊姆，獲得了50G")
        elif outcome_c == ["Miss, 金屬史萊姆迅速地躲開了"]:
            print(outcome_c)
            print(act_f)
            if act_f == ["金屬史萊姆逃走了!"]:
                print("怪物集團消失了")
            elif act_f == ["金屬史萊姆正在觀察情況。"]:
                return rpg()
    elif x == "要害突刺":
        print(name,"的攻擊,",name,"朝著敵人的要害攻擊")
        if outcome_d == ["會心一擊,對金屬史萊姆造成了8點傷害"]:
            print(outcome_d)
            hp = hp - 8
            if hp > 0:
                print(act_f)
                if act_f == ["金屬史萊姆逃走了!"]:
                    print("怪物集團消失了")
                elif act_f == ["金屬史萊姆正在觀察情況。"]:
                    return rpg()
            elif hp < 0:
                print(name,"打倒了金屬史萊姆，獲得了50G")
        elif outcome_d == ["Miss, 金屬史萊姆迅速地躲開了"]:
            print(outcome_d)
            print(act_f)
            if act_f == ["金屬史萊姆逃走了!"]:
                print("怪物集團消失了")
            elif act_f == ["金屬史萊姆正在觀察情況。"]:
                return rpg()
rpg()
# Out:
# 請輸入角色名稱:山
# 金屬史萊姆出現了
# 請選擇指令:金屬斬/隼斬/魔神斬/要害突刺金屬斬
# 山 的攻擊, 山 使出了金屬斬
# ['Miss, 金屬史萊姆迅速地躲開了']
# ['金屬史萊姆正在觀察情況。']
# 請選擇指令:金屬斬/隼斬/魔神斬/要害突刺金屬斬
# 山 的攻擊, 山 使出了金屬斬
# ['對金屬史萊姆造成3點的傷害']
# ['金屬史萊姆正在觀察情況。']
# 請選擇指令:金屬斬/隼斬/魔神斬/要害突刺金屬斬
# 山 的攻擊, 山 使出了金屬斬
# ['對金屬史萊姆造成3點的傷害']
# 山 打倒了金屬史萊姆，獲得了50G
